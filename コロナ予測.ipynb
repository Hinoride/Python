# %%
# install a package
# !pip install covid19dh
# import libraries 
import pandas as pd
from matplotlib import pyplot as plt
from covid19dh import covid19
import datetime as dt
# load the data
x = covid19(verbose=False)
# infected japan
x, src = covid19("JPN", level = 1)
x.info()
japan = x.loc[4300:4336,['date', 'confirmed']]
japan.columns = ['ds', 'y']
japan
# https://facebook.github.io/prophet/docs/quick_start.html#r-api
import pandas as pd
from prophet import Prophet
# fit the data to prophet
m = Prophet()
m.fit(japan)
# show the future
future = m.make_future_dataframe(periods=20)
future.tail()
# forecast the future
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Python
fig1 = m.plot(forecast)
# automatic changepoint detection in Prophet
# https://facebook.github.io/prophet/docs/trend_changepoints.html
from prophet.plot import add_changepoints_to_plot
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# ...
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 3663 to 4336
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count  Dtype
# ...

# %%
# install a package
# !pip install covid19dh
# import libraries 
import pandas as pd
from matplotlib import pyplot as plt
from covid19dh import covid19
import datetime as dt
# load the data
x = covid19(verbose=False)
# infected japan
x, src = covid19("JPN", level = 1)
japan = x.loc[4300:4336,['confirmed']]
diff=np.diff(japan, axis=0)
diff2=np.diff(diff,axis=0)
plt.plot(diff)
plt.plot(diff2)
# Out:
# ...
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.

# %%
# install a package
# !pip install covid19dh
# import libraries 
import pandas as pd
from matplotlib import pyplot as plt
from covid19dh import covid19
import datetime as dt
import numpy as np
# load the data
x = covid19(verbose=False)
# infected japan
x, src = covid19("JPN", level = 1)

japan = x.loc[6600:6649,['confirmed']]


#japan = x.loc[29300:29360,['confirmed']]
diff=np.diff(japan, axis=0)
print(diff)
plt.plot(diff)
#diff2=np.diff(diff,axis=0)
#plt.plot('y')
# Out:
# ...
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# [[ 109.]
#  [  73.]
#  [ 116.]
#  [ 121.]
#  [ 123.]
#  [  72.]
#  [  81.]
#  [ 130.]
#  [ 119.]
#  [ 127.]
#  [ 142.]
#  [ 130.]
#  [ 112.]
#  [  59.]
#  [ 114.]
#  [ 131.]
#  [ 163.]
#  [ 143.]
#  [ 146.]
#  [ 115.]
#  [  77.]
#  [ 143.]
#  [ 174.]
#  [ 188.]
#  [ 182.]
#  [ 201.]
#  [ 177.]
#  [ 151.]
#  [ 247.]
#  [ 261.]
#  [ 294.]
#  [ 297.]
#  [ 320.]
#  [ 262.]
#  [ 212.]
#  [ 382.]
#  [ 498.]
# ...
